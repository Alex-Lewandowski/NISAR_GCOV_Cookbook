# %% [markdown]
# # PolSAR Placeholder Notebook
#
# :::{warning} Current state of NISAR data access
# At the time of writing (2025-12-04), there are no NISAR GCOV data in production and sample NISAR GCOV data do not contain off-diagonal covariance channels. We will develop PolSAR tutorials when data are available.
# :::
